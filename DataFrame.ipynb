# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()
nfl_frame
# Out:
# C:\bot\lib\site-packages\pandas\io\clipboards.py:63: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return read_table(StringIO(text), sep=sep, **kwargs)
#    Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0      3           Dallas Cowboys     882    502    374      6  0.573
# 1      2        Green Bay Packers   1,336    737    562     37  0.565
# 2      1            Chicago Bears   1,370    749    579     42  0.562
# 3      4           Miami Dolphins     800    445    351      4  0.559
# 4      5  New England Patriots[b]     884    489    386      9  0.558
# 5      6        Minnesota Vikings     870    470    390     10  0.546
#
#    First NFL Season    Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1920  NFC North
# 3               1966   AFC East
# 4               1960   AFC East
# 5               1961  NFC North

# %%
nfl_frame.columns
# Out:
# Index(['Rank ', 'Team ', 'GP ', 'Won ', 'Lost ', 'Tied ', 'Pct. ',
#        'First NFL Season ', 'Division'],
#       dtype='object')

# %%
nfl_frame['Team ']
# Out:
# 0             Dallas Cowboys
# 1          Green Bay Packers
# 2              Chicago Bears
# 3             Miami Dolphins
# 4    New England Patriots[b]
# 5          Minnesota Vikings
# Name: Team , dtype: object

# %%
nfl_frame[['Team ', 'First NFL Season ']]
# Out:
#                       Team   First NFL Season
# 0           Dallas Cowboys                1960
# 1        Green Bay Packers                1921
# 2            Chicago Bears                1920
# 3           Miami Dolphins                1966
# 4  New England Patriots[b]                1960
# 5        Minnesota Vikings                1961

# %%
DataFrame(nfl_frame, columns=['Team ', 'First NFL Season '])
# Out:
#                       Team   First NFL Season
# 0           Dallas Cowboys                1960
# 1        Green Bay Packers                1921
# 2            Chicago Bears                1920
# 3           Miami Dolphins                1966
# 4  New England Patriots[b]                1960
# 5        Minnesota Vikings                1961

# %%
DataFrame(nfl_frame, columns=['Team ', 'First NFL Season ', 'Stadium'])
# Out:
#                       Team   First NFL Season   Stadium
# 0           Dallas Cowboys                1960      NaN
# 1        Green Bay Packers                1921      NaN
# 2            Chicago Bears                1920      NaN
# 3           Miami Dolphins                1966      NaN
# 4  New England Patriots[b]                1960      NaN
# 5        Minnesota Vikings                1961      NaN

# %%
nfl_frame.shape
# Out:
# (6, 9)

# %%
nfl_frame.head(3)
# Out:
#    Rank                Team      GP   Won   Lost   Tied   Pct.   \
# 0      3     Dallas Cowboys     882    502    374      6  0.573
# 1      2  Green Bay Packers   1,336    737    562     37  0.565
# 2      1      Chicago Bears   1,370    749    579     42  0.562
#
#    First NFL Season    Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1920  NFC North

# %%
nfl_frame.tail(3)
# Out:
#    Rank                      Team    GP   Won   Lost   Tied   Pct.   \
# 3      4           Miami Dolphins   800    445    351      4  0.559
# 4      5  New England Patriots[b]   884    489    386      9  0.558
# 5      6        Minnesota Vikings   870    470    390     10  0.546
#
#    First NFL Season    Division
# 3               1966   AFC East
# 4               1960   AFC East
# 5               1961  NFC North

# %%
nfl_frame.ix[3]
# Out:
# C:\bot\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# Rank                               4
# Team                 Miami Dolphins
# GP                              800
# Won                              445
# Lost                             351
# Tied                               4
# Pct.                           0.559
# First NFL Season                1966
# Division                    AFC East
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0      3           Dallas Cowboys     882    502    374      6  0.573
# 1      2        Green Bay Packers   1,336    737    562     37  0.565
# 2      1            Chicago Bears   1,370    749    579     42  0.562
# 3      4           Miami Dolphins     800    445    351      4  0.559
# 4      5  New England Patriots[b]     884    489    386      9  0.558
# 5      6        Minnesota Vikings     870    470    390     10  0.546
#
#    First NFL Season    Division         Stadium
# 0               1960   NFC East  Levi's Stadium
# 1               1921  NFC North  Levi's Stadium
# 2               1920  NFC North  Levi's Stadium
# 3               1966   AFC East  Levi's Stadium
# 4               1960   AFC East  Levi's Stadium
# 5               1961  NFC North  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(6)

# %%
nfl_frame
# Out:
#    Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0      3           Dallas Cowboys     882    502    374      6  0.573
# 1      2        Green Bay Packers   1,336    737    562     37  0.565
# 2      1            Chicago Bears   1,370    749    579     42  0.562
# 3      4           Miami Dolphins     800    445    351      4  0.559
# 4      5  New England Patriots[b]     884    489    386      9  0.558
# 5      6        Minnesota Vikings     870    470    390     10  0.546
#
#    First NFL Season    Division  Stadium
# 0               1960   NFC East        0
# 1               1921  NFC North        1
# 2               1920  NFC North        2
# 3               1966   AFC East        3
# 4               1960   AFC East        4
# 5               1961  NFC North        5

# %%
stadiums = Series(["Levi's stadium", 'AT&Y Stadium'], index=[4,0])

# %%
stadiums
# Out:
# 4    Levi's stadium
# 0      AT&Y Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = stadiums

# %%
nfl_frame
# Out:
#    Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0      3           Dallas Cowboys     882    502    374      6  0.573
# 1      2        Green Bay Packers   1,336    737    562     37  0.565
# 2      1            Chicago Bears   1,370    749    579     42  0.562
# 3      4           Miami Dolphins     800    445    351      4  0.559
# 4      5  New England Patriots[b]     884    489    386      9  0.558
# 5      6        Minnesota Vikings     870    470    390     10  0.546
#
#    First NFL Season    Division         Stadium
# 0               1960   NFC East    AT&Y Stadium
# 1               1921  NFC North             NaN
# 2               1920  NFC North             NaN
# 3               1966   AFC East             NaN
# 4               1960   AFC East  Levi's stadium
# 5               1961  NFC North             NaN

# %%
del nfl_frame['Stadium']

# %%
nfl_frame
# Out:
#    Rank                      Team      GP   Won   Lost   Tied   Pct.   \
# 0      3           Dallas Cowboys     882    502    374      6  0.573
# 1      2        Green Bay Packers   1,336    737    562     37  0.565
# 2      1            Chicago Bears   1,370    749    579     42  0.562
# 3      4           Miami Dolphins     800    445    351      4  0.559
# 4      5  New England Patriots[b]     884    489    386      9  0.558
# 5      6        Minnesota Vikings     870    470    390     10  0.546
#
#    First NFL Season    Division
# 0               1960   NFC East
# 1               1921  NFC North
# 2               1920  NFC North
# 3               1966   AFC East
# 4               1960   AFC East
# 5               1961  NFC North

# %%
data = {'City':['SF', 'LA', 'NYC'], 'Population': [837000,3880000,840000]}

# %%
data
# Out:
# {'City': ['SF', 'LA', 'NYC'], 'Population': [837000, 3880000, 840000]}

# %%
city_frame = DataFrame(data)

# %%
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC      840000
